# %%
from database import (
    get_goals,
    get_domain_weights,
    get_recent_logs,
    get_recent_evaluations,
    get_recent_plans
)

goals = get_goals()
weights = get_domain_weights()
logs = get_recent_logs()
evaluations = get_recent_evaluations()
plans = get_recent_plans()

print("=== JOVAN OS STATUS ===")
print()

print(f"Goals: {len(goals)}")
print(f"Logs: {len(logs)}")
print(f"Evaluations: {len(evaluations)}")
print(f"Plans: {len(plans)}")
# Out:
# === JOVAN OS STATUS ===
#
# Goals: 20
# Logs: 5
# Evaluations: 8
# Plans: 3

# %%
print("=== ACTIVE GOALS ===")
print()

for goal in goals:
    print(f"- {goal[2]}")
# Out:
# === ACTIVE GOALS ===
#
# - Završiti ETF master
# - Završiti ETF master
# - Završiti ETF master
# - Završiti ETF master
# - Završiti ETF master
# - Prvi AI prihod
# - Prvi AI prihod
# - Prvi AI prihod
# - Prvi AI prihod
# - Prvi AI prihod
# - Napraviti AI projekte
# - Napraviti AI projekte
# - Napraviti AI projekte
# - Napraviti AI projekte
# - Napraviti AI projekte
# - Doći do 90kg
# - Doći do 90kg
# - Doći do 90kg
# - Doći do 90kg
# - Doći do 90kg

# %%
print("=== DOMAIN WEIGHTS ===")
print()

for domain, weight in weights:
    print(f"{domain}: {weight}%")
# Out:
# === DOMAIN WEIGHTS ===
#
# formalno_obrazovanje: 30%
# karijera: 20%
# neformalno_obrazovanje: 25%
# sport: 25%

# %%
latest = evaluations[0]

print("=== LAST SCORE ===")
print()

print(f"Score: {latest[2]}/10")
print()
print(latest[3][:500])
# Out:
# === LAST SCORE ===
#
# Score: 7.1/10
#
# # Overall score: 7.1/10
#
# ## Formal education: 8/10
# 90 min DOS2 je solidan i direktno prati visoko prioritetni cilj ETF mastera.
#
# ## Informal education: 8/10
# 60 min na Jovan OS structured output je primenjen rad, koristan za AI projekte i izgradnju sistema.
#
# ## Sport: 7.5/10
# Trening grudi + triceps održava kontinuitet, ali nema podataka o progresiji, mobilnosti ili eksplozivnosti.
#
# ## Career: 3/10
# Nije bilo direktnog karijernog koraka: bez monetizacije, outreach-a, prijava, networking-a ili portf

# %%
latest_plan = plans[0]

print("=== CURRENT PLAN ===")
print()

print(latest_plan[1][:800])
# Out:
# === CURRENT PLAN ===
#
# # Daily Plan
#
# ## Summary
# Imaš oko 4 sata i dobru energiju, pa je najrealnije da glavni fokus ide na **ETF** i **Jovan OS**, uz obavezan **trening** i mali **career output** kroz vidljiv rezultat iz Jovan OS rada.
#
# ## Priority Tasks
#
# ### Formal Education
# - 90 min ETF / DOS2 fokus blok
# - Rešavanje najtežeg ili najvažnijeg zadatka/poglavlja
# - 10 min kratka rekapitulacija i beleške
#
# ### Informal Education
# - 60 min Jovan OS rad na jednoj konkretnoj funkcionalnosti
# - Bez širine: samo jedan jasan deliverable danas
#
# ### Sport
# - 50 min trening snage ili gym session
# - 10 min mobilnost / istezanje na kraju
#
# ### Career
# - 20 min da Jovan OS postane vidljiv asset
# - GitHub update, kratak changelog, ili portfolio beleška
#
# ## Time Allocation
# | Activity | Duration |
# |----------|----------|
# | ETF / DOS2 deep
